# %%
import numpy as np
import scipy
import pickle
import random
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Set random seed
RANDOM_SEED = 1234
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# %%
verbose = True
# Generate test graph instances
for num_edges in [500, 1000, 1500]:
    num_nodes = int(np.floor(num_edges*0.6))
    for instance in range(20):
        print(instance)
        points = np.random.uniform(0,1000,size=(num_nodes,2)) # generate random vertex coordinates on 2d plane
        delaunay = scipy.spatial.Delaunay(points) # compute Delaunay triangulation for the points
        
#         # plot graph
#         plt.triplot(points[:,0], points[:,1], delaunay.simplices.copy())
#         plt.plot(points[:,0], points[:,1], 'o')
#         plt.show()
        
        # create networkx graph from graph
        G = nx.Graph()
        G.add_nodes_from(range(num_nodes)) # add a vertex for each spatial point
        indices, indptr = delaunay.vertex_neighbor_vertices # get indices of neighbors of each vertex
        for k in range(num_nodes):
            neighbor_nodes = indptr[indices[k]:indices[k+1]]
            for n in neighbor_nodes:
                G.add_edge(k,n)
        is_planar, embedding = nx.planarity.check_planarity(G)
        assert is_planar, 'Networkx graph created was not planar'

        # remove edges until we have the target number of edges
        G_num_nodes = len(G.nodes())
        G_num_edges = len(G.edges())
        assert len(G.edges()) > num_edges, 'Initial graph has too few edges'
        while G_num_edges > num_edges:
            i = random.sample(range(G_num_edges), 1)[0]
            e_remove = list(G.edges())[i]
            G.remove_edge(e_remove[0], e_remove[1])
            is_connected = nx.is_connected(G)
            if is_connected:
                G_num_edges = len(G.edges())
            else:
                G.add_edge(e_remove[0], e_remove[1])
        assert len(G.edges()) == num_edges, 'Graph does not have the target number of edges.'
        assert nx.is_connected(G), 'Graph is not connected.'

        # remove any degree 0 nodes
        degrees = list(G.degree())
        for v in degrees:
            if v[1] == 0:
                G.remove_node(v[0])
        G = nx.convert_node_labels_to_integers(G)
        V = [v for v in G.nodes()]
        E = list(G.edges())
        
        if verbose:
            print('Graph has %d nodes and %d edges in total.'%(len(V),len(E)))
            print('Mean degree: %0.2f'%np.mean([v[1] for v in G.degree()]))
        # check if the graph instance has cycles
        if verbose:
            print('The graph instance has %d cycles.'%len(nx.cycle_basis(G)))
            print('---------------------------------------')
        nx.write_graphml(G,"../data/synthetic_graphs/planar/graphs/G_n_edges_%d_instance_%d.graphml"%(len(E), instance)) # save graph                

        # generate costs
        cost_E = dict()
        for e in E:
            cost = np.random.rand()
            cost_E[e] = cost
        total_cost = sum([cost_E[i] for i in E])
        G_spanning_tree_edges = nx.minimum_spanning_edges(G, data=False)
        total_mst_cost = sum([cost_E[i] for i in G_spanning_tree_edges])
        print(total_mst_cost)
        cost_data = (cost_E, total_cost, total_mst_cost)
        pickle.dump(cost_data, open("../data/synthetic_graphs/planar/edge_costs/G_n_edges_%d_instance_%d_cost_data.p"%(len(E), instance), "wb"))
        
        # initialize demand between each source-destination pair
        SD = []
        for s in V:
            for d in V:
                SD.append((s,d))
                SD.append((d,s))
        SD = list(set(SD))
        demand = dict.fromkeys(SD)
        for vpair in SD:
            s = vpair[0]
            d = vpair[1]
            if s != d:
                demand[(s,d)] = np.random.randint(1,200)
                demand[(d,s)] = np.random.randint(1,200)
            else:
                demand[(s,d)] = 0
                demand[(d,s)] = 0
        pickle.dump(demand, open("../data/synthetic_graphs/planar/demands/G_n_edges_%d_instance_%d_demand_data.p"%(len(E), instance), "wb" ))

        # translate demand to values for each edge in isolation (used by supermodular heuristic)
        values = dict()
        for e in E:
            values[e] = demand[(e[0], e[1])] + demand[(e[1], e[0])]
        pickle.dump(values, open("../data/synthetic_graphs/planar/edge_values/G_n_edges_%d_instance_%d_edge_values_data.p"%(len(E), instance), "wb" ))
# Out:
# 0
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 152.807666437
# 1
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 148.244018452
# 2
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 147.91062131
# 3
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 152.818464632
# 4
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 150.202910959
# 5
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 156.080232919
# 6
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 143.979610407
# 7
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 151.820815227
# 8
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 150.522450072
# 9
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 150.806112205
# 10
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 147.280317201
# 11
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 143.126329969
# 12
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 146.562295313
# 13
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 156.857755358
# 14
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 150.647698936
# 15
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 139.545684216
# 16
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 142.950750241
# 17
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 148.905651509
# 18
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 142.280020455
# 19
# Graph has 300 nodes and 500 edges in total.
# Mean degree: 3.33
# The graph instance has 201 cycles.
# ---------------------------------------
# 144.78135164
# 0
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 292.913692332
# 1
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 309.969265326
# 2
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 306.498168211
# 3
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 295.103974253
# 4
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 302.968883216
# 5
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 293.811998415
# 6
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 296.431873457
# 7
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 290.129740811
# 8
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 278.12500533
# 9
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 303.532525204
# 10
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 300.413774164
# 11
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 295.728031839
# 12
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 298.821037806
# 13
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 300.806965792
# 14
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 299.618169148
# 15
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 301.707573462
# 16
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 307.01823991
# 17
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 278.624109351
# 18
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 300.422550253
# 19
# Graph has 600 nodes and 1000 edges in total.
# Mean degree: 3.33
# The graph instance has 401 cycles.
# ---------------------------------------
# 300.432505024
# 0
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 446.539494228
# 1
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 457.808917816
# 2
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 440.87160643
# 3
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 454.641302326
# 4
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 454.866153921
# 5
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 438.894477036
# 6
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 442.71154191
# 7
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 433.216562866
# 8
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 444.55739898
# 9
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 445.645040745
# 10
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 444.001120735
# 11
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 456.429616437
# 12
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 453.18266932
# 13
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 447.928960352
# 14
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 442.501246784
# 15
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 446.675404767
# 16
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 449.611276174
# 17
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 455.032144502
# 18
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 445.657365211
# 19
# Graph has 900 nodes and 1500 edges in total.
# Mean degree: 3.33
# The graph instance has 601 cycles.
# ---------------------------------------
# 465.623418386
